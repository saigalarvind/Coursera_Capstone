# %% [markdown]
# # **Coursera Capstone Project - Week 5**
# ### Author: Arvind Saigal
#
# ## **------------------------------------------------------------------------------------------------------------------------------------------------------------------------**
# ### _**About the project**_
# #### 1. **The following script helps potential clients who are looking to buy suitable property in London**
# #### 2. **With a pre-determined budged, this automation will recommend you locations and current average price of real estate where one can make a real estate investment**
# #### 3. **Important amenities/ venues for each recommended location are displayed**
# #### 4. **Facilities like elementary schools, high schools, hospitals & grocery stores are displayed for each recommended location**
# ## **------------------------------------------------------------------------------------------------------------------------------------------------------------------------**

# %%
import os # Operating System
import numpy as np
import pandas as pd
import datetime as dt # Datetime
import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# !conda install -c conda-forge folium=0.5.0 --yes
import folium #import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.0.2p             |       h470a237_1         3.1 MB  conda-forge
#     certifi-2018.10.15         |        py36_1000         138 KB  conda-forge
#     geopy-1.17.0               |             py_0          49 KB  conda-forge
#     ca-certificates-2018.10.15 |       ha4d7672_0         135 KB  conda-forge
#     conda-4.5.11               |        py36_1000         651 KB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.1 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.49-py_0            conda-forge
#     geopy:           1.17.0-py_0          conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2018.8.24-ha4d7672_0 conda-forge --> 2018.10.15-ha4d7672_0 conda-forge
#     certifi:         2018.8.24-py36_1001  conda-forge --> 2018.10.15-py36_1000  conda-forge
#     conda:           4.5.11-py36_0        conda-forge --> 4.5.11-py36_1000      conda-forge
#     openssl:         1.0.2p-h470a237_0    conda-forge --> 1.0.2p-h470a237_1     conda-forge
#
#
# Downloading and Extracting Packages
# openssl-1.0.2p       | 3.1 MB    | ##################################### | 100%
# certifi-2018.10.15   | 138 KB    | ##################################### | 100%
# geopy-1.17.0         | 49 KB     | ##################################### | 100%
# ca-certificates-2018 | 135 KB    | ##################################### | 100%
# conda-4.5.11         | 651 KB    | ##################################### | 100%
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-2.2.2               |        py36_1001         494 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     branca-0.3.0               |             py_0          24 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         592 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py36_1001 conda-forge
#     branca:  0.3.0-py_0      conda-forge
#     folium:  0.5.0-py_0      conda-forge
#     vincent: 0.4.4-py_1      conda-forge
#
#
# Downloading and Extracting Packages
# altair-2.2.2         | 494 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# branca-0.3.0         | 24 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %%
# Set the present working directory
os.chdir("/resources/data/Coursera")

# %% [markdown]
# #### **Source of dataset: http://landregistry.data.gov.uk/**

# %%
# Read the data for examination (Source: http://landregistry.data.gov.uk/)
df_ppd = pd.read_csv("Price_Paid_Data.csv")

# Assign meaningful column names
df_ppd.columns = ['TUID', 'Price', 'Date_Transfer', 'Postcode', 'Prop_Type', 'Old_New', 'Duration', 'PAON', \
                  'SAON', 'Street', 'Locality', 'Town_City', 'District', 'County', 'PPD_Cat_Type', 'Record_Status']

# %%
# Format the date column
df_ppd['Date_Transfer'] = df_ppd['Date_Transfer'].apply(pd.to_datetime)

# Delete all obsolete transactions which were done before 2016
df_ppd.drop(df_ppd[df_ppd.Date_Transfer.dt.year < 2016].index, inplace=True)

# Sort by Date of Sale
df_ppd.sort_values(by=['Date_Transfer'],ascending=[False],inplace=True)

# %% [markdown]
# #### **Select data only for city of LONDON**

# %%
df_ppd_london = df_ppd.query("Town_City == 'LONDON'")

# Make a list of street names in LONDON
streets = df_ppd_london['Street'].unique().tolist()

# %% [markdown]
# #### **Calculate the street-wise average price of the property**

# %%
df_grp_price = df_ppd_london.groupby(['Street'])['Price'].mean().reset_index()

# Give meaningful names to the columns
df_grp_price.columns = ['Street', 'Avg_Price']

# %% [markdown]
# ## **Input your Budget's Upper Limit and Lower Limit**
#
# #### **Find the locations df_grp_price which fits your budget**
#
# #### **Please change the limits as per your budget**

# %%
df_affordable = df_grp_price.query("(Avg_Price >= 2200000) & (Avg_Price <= 2500000)")

# %%
# Display the dataframe
df_affordable
# Out:
#                      Street     Avg_Price
# 45       ALBERT BRIDGE ROAD  2.383333e+06
# 299            BELSIZE LANE  2.350000e+06
# 538         BURNSALL STREET  2.286500e+06
# 553           BUSHNELL ROAD  2.200000e+06
# 675         CHALCOT GARDENS  2.200000e+06
# 773        CIRCUS ROAD WEST  2.448032e+06
# 903   CORNWALL TERRACE MEWS  2.350000e+06
# 913      COURT LANE GARDENS  2.360000e+06
# 1085             DORIA ROAD  2.325000e+06
# 1131    DULWICH WOOD AVENUE  2.297000e+06
# 1185            EDGE STREET  2.200000e+06
# 1192           EDITH VILLAS  2.402500e+06
# 1210         ELLERBY STREET  2.465000e+06
# 1371          FORDWYCH ROAD  2.290000e+06
# 1393        FRANK DIXON WAY  2.212500e+06
# 1540           GRANARD ROAD  2.500000e+06
# 1934      JOHN ISLIP STREET  2.200000e+06
# 2040          LADBROKE ROAD  2.261250e+06
# 2060        LANCHESTER ROAD  2.300000e+06
# 2152    LEWIS CUBITT SQUARE  2.225300e+06
# 2329       MARLBOROUGH HILL  2.278000e+06
# 2488            MULTON ROAD  2.300000e+06
# 2830            PORTEN ROAD  2.200000e+06
# 2838        PORTOBELLO ROAD  2.217166e+06
# 2876            PRIORY ROAD  2.410000e+06
# 2914        QUEENSMERE ROAD  2.300000e+06
# 2925        RADSTOCK STREET  2.200000e+06
# 2940         RATHBONE PLACE  2.480038e+06
# 2996          RIDGWAY PLACE  2.500000e+06
# 3056          ROTHBURY ROAD  2.371700e+06
# 3077           ROYSTON ROAD  2.250000e+06
# 3134         SAVERNAKE ROAD  2.212500e+06
# 3250        SOUTH HILL PARK  2.466667e+06
# 3407      STRATHRAY GARDENS  2.350000e+06
# 3495        TEIGNMOUTH ROAD  2.295000e+06
# 3572     THURLOE PLACE MEWS  2.300000e+06
# 3578           TIERNEY LANE  2.221667e+06
# 3832       WESTBOURNE GROVE  2.300000e+06
# 3846      WESTMORELAND ROAD  2.350000e+06

# %% [markdown]
# #### **Read the street-wise coordinates into a dataframe**

# %%
london_data = pd.read_csv("Street Coordinates London.csv")

# Eliminate recurring word LONDON from individual names
london_data['Street'] = london_data['Street'].str.replace(', LONDON', '')

# %% [markdown]
# #### **Join the data to find the coordinates of locations which fit into client's budget**

# %%
df_pref_loc = pd.merge(london_data, df_affordable, on=['Street'], how='inner')

# %%
df_pref_loc.head(10)
# Out:
#    Unnamed: 0               Street   Latitude  Longitude     Avg_Price
# 0          77  DULWICH WOOD AVENUE  51.425586  -0.082416  2.297000e+06
# 1         251      SOUTH HILL PARK  51.557134  -0.164343  2.466667e+06
# 2         407      TEIGNMOUTH ROAD  51.550139  -0.214496  2.295000e+06
# 3         729      BURNSALL STREET  51.489042  -0.166883  2.286500e+06
# 4         948        FORDWYCH ROAD  51.551511  -0.206736  2.290000e+06
# 5        1044          PORTEN ROAD  51.498603  -0.214120  2.200000e+06
# 6        1058   ALBERT BRIDGE ROAD  51.477861  -0.164743  2.383333e+06
# 7        1137         EDITH VILLAS  51.491665  -0.206556  2.402500e+06
# 8        1322     WESTBOURNE GROVE  51.514797  -0.197071  2.300000e+06
# 9        1336        LADBROKE ROAD  51.508776  -0.203410  2.261250e+06

# %% [markdown]
# ## **Let's plot recommended locations on map of London with current market prices**

# %%
address = 'London, UK'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of London City are {}, {}.'.format(latitude, longitude))
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning
# The geograpical coordinate of London City are 51.5073219, -0.1276474.

# %%
# create map of Manhattan using latitude and longitude values
map_london = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, price, street in zip(df_pref_loc['Latitude'], df_pref_loc['Longitude'], df_pref_loc['Avg_Price'], df_pref_loc['Street']):
    label = '{}, {}'.format(street, price)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_london)  
    
map_london
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = '******' # your Foursquare ID
CLIENT_SECRET = '*******' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)

# %% [markdown]
# #### Let's explore the first neighborhood in our dataframe.

# %% [markdown]
# ## 2. Explore the preferred location for different venues

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500, LIMIT=100):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Street', 
                  'Street Latitude', 
                  'Street Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# #### Now write the code to run the above function on each location and create a new dataframe called *location_venues* and display it.

# %%
# type your answer here
location_venues = getNearbyVenues(names=df_pref_loc['Street'],
                                   latitudes=df_pref_loc['Latitude'],
                                   longitudes=df_pref_loc['Longitude']
                                  )
# Out:
# DULWICH WOOD AVENUE
# SOUTH HILL PARK
# TEIGNMOUTH ROAD
# BURNSALL STREET
# FORDWYCH ROAD
# PORTEN ROAD
# ALBERT BRIDGE ROAD
# EDITH VILLAS
# WESTBOURNE GROVE
# LADBROKE ROAD
# PORTOBELLO ROAD
# STRATHRAY GARDENS
# WESTMORELAND ROAD
# PRIORY ROAD
# LEWIS CUBITT SQUARE
# QUEENSMERE ROAD
# RIDGWAY PLACE
# DORIA ROAD
# SAVERNAKE ROAD
# MARLBOROUGH HILL
# ELLERBY STREET
# CHALCOT GARDENS
# EDGE STREET
# MULTON ROAD
# CORNWALL TERRACE MEWS
# JOHN ISLIP STREET
# COURT LANE GARDENS
# FRANK DIXON WAY
# BUSHNELL ROAD
# THURLOE PLACE MEWS
# BELSIZE LANE
# RATHBONE PLACE
# GRANARD ROAD
# ROYSTON ROAD
# RADSTOCK STREET
# LANCHESTER ROAD
# CIRCUS ROAD WEST
# TIERNEY LANE
# ROTHBURY ROAD

# %%
location_venues
# Out:
#                    Street  Street Latitude  Street Longitude  \
# 0     DULWICH WOOD AVENUE        51.425586         -0.082416
# 1     DULWICH WOOD AVENUE        51.425586         -0.082416
# 2     DULWICH WOOD AVENUE        51.425586         -0.082416
# 3     DULWICH WOOD AVENUE        51.425586         -0.082416
# 4     DULWICH WOOD AVENUE        51.425586         -0.082416
# 5     DULWICH WOOD AVENUE        51.425586         -0.082416
# 6         SOUTH HILL PARK        51.557134         -0.164343
# 7         SOUTH HILL PARK        51.557134         -0.164343
# 8         SOUTH HILL PARK        51.557134         -0.164343
# 9         SOUTH HILL PARK        51.557134         -0.164343
# 10        SOUTH HILL PARK        51.557134         -0.164343
# 11        SOUTH HILL PARK        51.557134         -0.164343
# 12        SOUTH HILL PARK        51.557134         -0.164343
# 13        SOUTH HILL PARK        51.557134         -0.164343
# 14        SOUTH HILL PARK        51.557134         -0.164343
# 15        SOUTH HILL PARK        51.557134         -0.164343
# 16        SOUTH HILL PARK        51.557134         -0.164343
# 17        SOUTH HILL PARK        51.557134         -0.164343
# 18        SOUTH HILL PARK        51.557134         -0.164343
# 19        SOUTH HILL PARK        51.557134         -0.164343
# 20        SOUTH HILL PARK        51.557134         -0.164343
# 21        SOUTH HILL PARK        51.557134         -0.164343
# 22        SOUTH HILL PARK        51.557134         -0.164343
# 23        SOUTH HILL PARK        51.557134         -0.164343
# 24        SOUTH HILL PARK        51.557134         -0.164343
# 25        SOUTH HILL PARK        51.557134         -0.164343
# 26        SOUTH HILL PARK        51.557134         -0.164343
# 27        SOUTH HILL PARK        51.557134         -0.164343
# 28        SOUTH HILL PARK        51.557134         -0.164343
# 29        SOUTH HILL PARK        51.557134         -0.164343
# ...                   ...              ...               ...
# 1324         TIERNEY LANE        51.487221         -0.226058
# 1325         TIERNEY LANE        51.487221         -0.226058
# 1326         TIERNEY LANE        51.487221         -0.226058
# 1327        ROTHBURY ROAD        51.542196         -0.025609
rows x 7 columns]

# %%
location_venues.groupby('Street').count()
# Out:
#                        Street Latitude  Street Longitude  Venue  \
# Street
# ALBERT BRIDGE ROAD                  17                17     17
# BELSIZE LANE                        25                25     25
# BURNSALL STREET                     74                74     74
# BUSHNELL ROAD                        4                 4      4
# CHALCOT GARDENS                     29                29     29
# CIRCUS ROAD WEST                    23                23     23
# CORNWALL TERRACE MEWS               85                85     85
# COURT LANE GARDENS                  12                12     12
# DORIA ROAD                          60                60     60
# DULWICH WOOD AVENUE                  6                 6      6
# EDGE STREET                         46                46     46
# EDITH VILLAS                        40                40     40
# ELLERBY STREET                      21                21     21
# FORDWYCH ROAD                        8                 8      8
# FRANK DIXON WAY                      7                 7      7
# GRANARD ROAD                        10                10     10
# JOHN ISLIP STREET                   63                63     63
# LADBROKE ROAD                       65                65     65
# LANCHESTER ROAD                      3                 3      3
# LEWIS CUBITT SQUARE                 46                46     46
# MARLBOROUGH HILL                    16                16     16
# MULTON ROAD                          4                 4      4
# PORTEN ROAD                         33                33     33
# PORTOBELLO ROAD                     76                76     76
# PRIORY ROAD                         15                15     15
# QUEENSMERE ROAD                      5                 5      5
# RADSTOCK STREET                     12                12     12
# RATHBONE PLACE                     100               100    100
# RIDGWAY PLACE                       34                34     34
# ROTHBURY ROAD                       27                27     27
# ROYSTON ROAD                        20                20     20
# SAVERNAKE ROAD                      15                15     15
# SOUTH HILL PARK                     30                30     30
# STRATHRAY GARDENS                   54                54     54
# TEIGNMOUTH ROAD                     14                14     14
# THURLOE PLACE MEWS                 100               100    100
# TIERNEY LANE                        28                28     28
# WESTBOURNE GROVE                   100               100    100
# WESTMORELAND ROAD                   27                27     27
#
#                        Venue Latitude  Venue Longitude  Venue Category
# Street
# ALBERT BRIDGE ROAD                 17               17              17
# BELSIZE LANE                       25               25              25
# BURNSALL STREET                    74               74              74
# BUSHNELL ROAD                       4                4               4
# CHALCOT GARDENS                    29               29              29
# CIRCUS ROAD WEST                   23               23              23
# CORNWALL TERRACE MEWS              85               85              85
# COURT LANE GARDENS                 12               12              12
# DORIA ROAD                         60               60              60
# DULWICH WOOD AVENUE                 6                6               6
# EDGE STREET                        46               46              46
# EDITH VILLAS                       40               40              40
# ELLERBY STREET                     21               21              21
# FORDWYCH ROAD                       8                8               8
# FRANK DIXON WAY                     7                7               7
# GRANARD ROAD                       10               10              10
# JOHN ISLIP STREET                  63               63              63
# LADBROKE ROAD                      65               65              65
# LANCHESTER ROAD                     3                3               3
# LEWIS CUBITT SQUARE                46               46              46
# MARLBOROUGH HILL                   16               16              16
# MULTON ROAD                         4                4               4
# PORTEN ROAD                        33               33              33
# PORTOBELLO ROAD                    76               76              76
# PRIORY ROAD                        15               15              15
# QUEENSMERE ROAD                     5                5               5
# RADSTOCK STREET                    12               12              12
# RATHBONE PLACE                    100              100             100
# RIDGWAY PLACE                      34               34              34
# ROTHBURY ROAD                      27               27              27
# ROYSTON ROAD                       20               20              20
# SAVERNAKE ROAD                     15               15              15
# SOUTH HILL PARK                    30               30              30
# STRATHRAY GARDENS                  54               54              54
# TEIGNMOUTH ROAD                    14               14              14
# THURLOE PLACE MEWS                100              100             100
# TIERNEY LANE                       28               28              28
# WESTBOURNE GROVE                  100              100             100
# WESTMORELAND ROAD                  27               27              27

# %% [markdown]
# #### Let's explore the first neighborhood in our dataframe.

# %%
def getNearbyFacility(names, latitudes, longitudes, radius=5000):
    
    facility_list=[]
    
    radius = 5000
    LIMIT = 100
    categories = '4bf58dd8d48988d196941735,58daa1558bbb0b01f18ec1f7,4bf58dd8d48988d13d941735,4f4533804b9074f6e4fb0105,4bf58dd8d48988d118951735'
    
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/search?&categoryId={}&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
        categories,
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        lat, 
        lng, 
        radius, 
        LIMIT)

        # make the GET request
        results = requests.get(url).json()['response']

        # return only relevant information for each nearby venue
        facility_list.append([(
            name,
            facility['name'],
            facility['categories'][0]['name'],
            facility['location']['distance'], 
            facility['location']['lat'],
            facility['location']['lng']) for facility in results['venues']])

    nearby_facility = pd.DataFrame([item for f_list in facility_list for item in f_list])
    nearby_facility.columns = ['Street Name',
                  'Facility Name',             
                  'Facility Category', 
                  'Distance', 
                  'Facility Latitude', 
                  'Facility Longitude']
    
    return(nearby_facility)

# %%
location_facility = getNearbyFacility(names=df_pref_loc['Street'],
                                      latitudes=df_pref_loc['Latitude'],
                                      longitudes=df_pref_loc['Longitude']
                                  )
# Out:
# DULWICH WOOD AVENUE
# SOUTH HILL PARK
# TEIGNMOUTH ROAD
# BURNSALL STREET
# FORDWYCH ROAD
# PORTEN ROAD
# ALBERT BRIDGE ROAD
# EDITH VILLAS
# WESTBOURNE GROVE
# LADBROKE ROAD
# PORTOBELLO ROAD
# STRATHRAY GARDENS
# WESTMORELAND ROAD
# PRIORY ROAD
# LEWIS CUBITT SQUARE
# QUEENSMERE ROAD
# RIDGWAY PLACE
# DORIA ROAD
# SAVERNAKE ROAD
# MARLBOROUGH HILL
# ELLERBY STREET
# CHALCOT GARDENS
# EDGE STREET
# MULTON ROAD
# CORNWALL TERRACE MEWS
# JOHN ISLIP STREET
# COURT LANE GARDENS
# FRANK DIXON WAY
# BUSHNELL ROAD
# THURLOE PLACE MEWS
# BELSIZE LANE
# RATHBONE PLACE
# GRANARD ROAD
# ROYSTON ROAD
# RADSTOCK STREET
# LANCHESTER ROAD
# CIRCUS ROAD WEST
# TIERNEY LANE
# ROTHBURY ROAD

# %%
location_facility
# Out:
#               Street Name                Facility Name  Facility Category  \
# 0     DULWICH WOOD AVENUE                        Tesco      Grocery Store
# 1     DULWICH WOOD AVENUE                        Tesco        Supermarket
# 2     DULWICH WOOD AVENUE              M&S Simply Food      Grocery Store
# 3     DULWICH WOOD AVENUE                        Tesco      Grocery Store
# 4     DULWICH WOOD AVENUE                        Tesco      Grocery Store
# 5     DULWICH WOOD AVENUE            Sainsbury's Local      Grocery Store
# 6     DULWICH WOOD AVENUE    telferscot primary school  Elementary School
# 7     DULWICH WOOD AVENUE  M&S Streatham Hill Foodhall      Grocery Store
# 8     DULWICH WOOD AVENUE        The Co-operative Food      Grocery Store
# 1944        ROTHBURY ROAD            Sainsbury's Local      Grocery Store
# 1945        ROTHBURY ROAD                       Palm 2      Grocery Store
# 1946        ROTHBURY ROAD                        Tesco      Grocery Store
# 1947        ROTHBURY ROAD                  Tesco Metro      Grocery Store
# 1948        ROTHBURY ROAD              M&S Simply Food      Grocery Store
# 1949        ROTHBURY ROAD                  Tesco Metro      Grocery Store
#
#       Distance  Facility Latitude  Facility Longitude
# 0         1311          51.436213           -0.090561
# 1         3911          51.397043           -0.049559
# 2         4513          51.389183           -0.111039
# 3         3677          51.445271           -0.124966
# 4         5315          51.438880           -0.155979
# 5         3749          51.446901           -0.124255
# 6         4250          51.442807           -0.137087
# 7         3419          51.439372           -0.126443
# 8         2306          51.440017           -0.106273
# 9         3216          51.398649           -0.099187
# 10        4836          51.468522           -0.093121
# 11        3634          51.401783           -0.118253
# 12        5529          51.471577           -0.112531
# 13        4642          51.465227           -0.103222
# 14        3386          51.426259           -0.131190
# 15        4366          51.432608           -0.020514
# 16        5169          51.448675           -0.017781
# 17        4934          51.381969           -0.069717
# 18        3155          51.440406           -0.121180
# 19        6212          51.470177           -0.028570
# 20        3811          51.404480           -0.039182
# 21        5228          51.468581           -0.112767
# 22        4831          51.385912           -0.110613
# 23        5618          51.420664           -0.162964
# 24        2754          51.449907           -0.075104
# 25        4790          51.446170           -0.021796
# 26        4187          51.443222           -0.029122
# 27        5324          51.379766           -0.104413
# 28        5788          51.470451           -0.124606
# 29        4052          51.406577           -0.032628
# ...        ...                ...                 ...
# 1920      2072          51.544418           -0.055336
# 1921      3551          51.538301           -0.076525
# 1922      3760          51.516239            0.009147
# 1923      4110          51.516702           -0.068551
# 1924      4728          51.527858           -0.089888
# 1925      5130          51.500540            0.006100
# 1926      5506          51.546981           -0.104777
# 1927      4392          51.526493           -0.083803
# 1928      4506          51.501714           -0.025619
# 1929      5744          51.498497           -0.069730
# 1930      4320          51.566971           -0.073653
# 1931      4090          51.562138           -0.075250
# 1932      4463          51.535693           -0.089223
# 1933      4431          51.552770           -0.087327
# 1934      2018          51.526893           -0.009975
# 1935      3997          51.516882           -0.066553
# 1936      4374          51.515596           -0.072096
# 1937      2665          51.527150           -0.055550
# 1938      5467          51.546781           -0.104233
# 1939      5747          51.504308           -0.081982
# 1940      5365          51.536001           -0.102466
# 1941      4896          51.508171            0.019192
# 1942      5554          51.513713           -0.091465
# 1943      4084          51.524588           -0.077357
# 1944      4430          51.517769           -0.076110
# 1945      2543          51.555853           -0.055062
# 1946      3396          51.512668           -0.037947
# 1947      5395          51.510810           -0.084977
# 1948      4385          51.503060           -0.018378
# 1949      4131          51.505166           -0.021658
#
# [1950 rows x 6 columns]

# %%
location_facility.groupby('Street Name').count()
# Out:
#                        Facility Name  Facility Category  Distance  \
# Street Name
# ALBERT BRIDGE ROAD                50                 50        50
# BELSIZE LANE                      50                 50        50
# BURNSALL STREET                   50                 50        50
# BUSHNELL ROAD                     50                 50        50
# CHALCOT GARDENS                   50                 50        50
# CIRCUS ROAD WEST                  50                 50        50
# CORNWALL TERRACE MEWS             50                 50        50
# COURT LANE GARDENS                50                 50        50
# DORIA ROAD                        50                 50        50
# DULWICH WOOD AVENUE               50                 50        50
# EDGE STREET                       50                 50        50
# EDITH VILLAS                      50                 50        50
# ELLERBY STREET                    50                 50        50
# FORDWYCH ROAD                     50                 50        50
# FRANK DIXON WAY                   50                 50        50
# GRANARD ROAD                      50                 50        50
# JOHN ISLIP STREET                 50                 50        50
# LADBROKE ROAD                     50                 50        50
# LANCHESTER ROAD                   50                 50        50
# LEWIS CUBITT SQUARE               50                 50        50
# MARLBOROUGH HILL                  50                 50        50
# MULTON ROAD                       50                 50        50
# PORTEN ROAD                       50                 50        50
# PORTOBELLO ROAD                   50                 50        50
# PRIORY ROAD                       50                 50        50
# QUEENSMERE ROAD                   50                 50        50
# RADSTOCK STREET                   50                 50        50
# RATHBONE PLACE                    50                 50        50
# RIDGWAY PLACE                     50                 50        50
# ROTHBURY ROAD                     50                 50        50
# ROYSTON ROAD                      50                 50        50
# SAVERNAKE ROAD                    50                 50        50
# SOUTH HILL PARK                   50                 50        50
# STRATHRAY GARDENS                 50                 50        50
# TEIGNMOUTH ROAD                   50                 50        50
# THURLOE PLACE MEWS                50                 50        50
# TIERNEY LANE                      50                 50        50
# WESTBOURNE GROVE                  50                 50        50
# WESTMORELAND ROAD                 50                 50        50
#
#                        Facility Latitude  Facility Longitude
# Street Name
# ALBERT BRIDGE ROAD                    50                  50
# BELSIZE LANE                          50                  50
# BURNSALL STREET                       50                  50
# BUSHNELL ROAD                         50                  50
# CHALCOT GARDENS                       50                  50
# CIRCUS ROAD WEST                      50                  50
# CORNWALL TERRACE MEWS                 50                  50
# COURT LANE GARDENS                    50                  50
# DORIA ROAD                            50                  50
# DULWICH WOOD AVENUE                   50                  50
# EDGE STREET                           50                  50
# EDITH VILLAS                          50                  50
# ELLERBY STREET                        50                  50
# FORDWYCH ROAD                         50                  50
# FRANK DIXON WAY                       50                  50
# GRANARD ROAD                          50                  50
# JOHN ISLIP STREET                     50                  50
# LADBROKE ROAD                         50                  50
# LANCHESTER ROAD                       50                  50
# LEWIS CUBITT SQUARE                   50                  50
# MARLBOROUGH HILL                      50                  50
# MULTON ROAD                           50                  50
# PORTEN ROAD                           50                  50
# PORTOBELLO ROAD                       50                  50
# PRIORY ROAD                           50                  50
# QUEENSMERE ROAD                       50                  50
# RADSTOCK STREET                       50                  50
# RATHBONE PLACE                        50                  50
# RIDGWAY PLACE                         50                  50
# ROTHBURY ROAD                         50                  50
# ROYSTON ROAD                          50                  50
# SAVERNAKE ROAD                        50                  50
# SOUTH HILL PARK                       50                  50
# STRATHRAY GARDENS                     50                  50
# TEIGNMOUTH ROAD                       50                  50
# THURLOE PLACE MEWS                    50                  50
# TIERNEY LANE                          50                  50
# WESTBOURNE GROVE                      50                  50
# WESTMORELAND ROAD                     50                  50
